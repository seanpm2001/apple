# %%
import apple

# %%
import matplotlib.pyplot as plt

# %%
# Lemniscate of Bernoulli: https://mathworld.wolfram.com/Lemniscate.html

# %%
lemni_x=apple.jit("λN. (λt. cos.t%(1+sin.t^2))'(frange 0 (2*𝜋) N)")

# %%
lemni_y=apple.jit("λN. (λt. sin. t*cos. t%(1+sin. t^2))'(frange 0 (2*𝜋) N)")

# %%
plt.plot(lemni_x(200),lemni_y(200))

# %%
# Aztema spiral https://www.2dcurves.com/spiral/spiralat.html

# %%
aztema_x=apple.jit("λN. (λt. sin.t%t-2*cos.t-t*sin. t)'(frange (1) (1+2*𝜋) N)")

# %%
aztema_y=apple.jit("λN. (λt. cos.t%t-2*sin.t+t*cos. t)'(frange (1) (1+2*𝜋) N)")

# %%
plt.plot(aztema_x(200),aztema_y(200))

# %%
# https://mathworld.wolfram.com/DevilsCurve.html

# %%
devil_x=apple.jit("λN. (λt. cos.t*√((sin. t^2-2*cos. t^2)%(sin. t^2-cos. t^2)))'(frange 0 (2*𝜋) N)")

# %%
devil_y=apple.jit("λN. (λt. sin.t*√((sin. t^2-2*cos. t^2)%(sin. t^2-cos. t^2)))'(frange 0 (2*𝜋) N)")

# %%
plt.plot(devil_x(700),devil_y(700))
